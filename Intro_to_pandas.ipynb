# %%
# Longitudinal data Time series data

# Matix data : Tabular data

# %%
import pandas as pd
import statistics as st

# %%
list1 = [20, 34,34,21,56,54,59]
list2 = [20, 34,34,21,56,54,59, 102]

# %%
st.mean(list1)
# Out:
# 39.714285714285715

# %%
st.mean(list2)
# Out:
# 47.5

# %%
import matplotlib.pyplot as plt

pd.DataFrame(list1).plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import matplotlib.pyplot as plt

pd.DataFrame(list2).plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
import pandas as pd

# %%
import seaborn as sb # we are using seaborn to gain access to the sample datasets it contains
# we are using sb as the alias for seaborn

# %%
sb.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# how to lad any of the seaborn sample datasets  

titanic_data = sb.load_dataset('titanic')

# %%
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# loading the diamonds data  

diamond_data = sb.load_dataset('diamonds')
diamond_data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
titanic_data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Saving the titanic data to a csv file

# to save any data to file in pandas we use the 
# filename.to_csv(fullsavepathand file.csv) for csv files
# filename.to_excel(fullsavepathand file.xls) for excel files
# filename.to_json(fullsavepathand file.json) for json files
# filename.to_txt(fullsavepathand file.txt) for txt files

# %%
# saving titanic data to csv file 


titanic_data = sb.load_dataset('titanic')

titanic_data.to_csv('c:/workspace/titanic_data.csv')

# %%
# saving titanic data to csv file without the index column saved


titanic_data = sb.load_dataset('titanic')

titanic_data.to_csv('c:/workspace/titanic_data1.csv',index = False)

# %%
# To load a csv file from a folder, use the following code

# pd.read_csv()

fileName = 'titanic_data1.csv'
filePath = 'C:/workspace/'

fullFilePath = filePath + fileName

print(fullFilePath)
# Out:
# C:/workspace/titanic_data1.csv

# %%
df = pd.read_csv('C:/workspace/titanic_data1.csv')

# %%
df
# Out:
#      survived  pclass      sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3     male  22.0      1      0   7.2500        S   Third
# 1           1       1  female   38.0      1      0  71.2833        C   First
# 2           1       3   female  26.0      0      0   7.9250        S   Third
# 3           1       1   female  35.0      1      0  53.1000        S   First
# 4           0       3     male  35.0      0      0   8.0500        S   Third
# ..        ...     ...      ...   ...    ...    ...      ...      ...     ...
# 886         0       2     male  27.0      0      0  13.0000        S  Second
# 887         1       1   female  19.0      0      0  30.0000        S   First
# 888         0       3  femalER   NaN      1      2  23.4500        S   Third
# 889         1       1     male  26.0      0      0  30.0000        C   First
# 890         0       3     male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
dfi = pd.read_csv(fullFilePath)
dfi
# Out:
#      survived  pclass      sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3     male  22.0      1      0   7.2500        S   Third
# 1           1       1  female   38.0      1      0  71.2833        C   First
# 2           1       3   female  26.0      0      0   7.9250        S   Third
# 3           1       1   female  35.0      1      0  53.1000        S   First
# 4           0       3     male  35.0      0      0   8.0500        S   Third
# ..        ...     ...      ...   ...    ...    ...      ...      ...     ...
# 886         0       2     male  27.0      0      0  13.0000        S  Second
# 887         1       1   female  19.0      0      0  30.0000        S   First
# 888         0       3  femalER   NaN      1      2  23.4500        S   Third
# 889         1       1     male  26.0      0      0  30.0000        C   First
# 890         0       3     male  32.0      0      0   7.7500        Q   Third
#
# ...

# %% [markdown]
# # Preliminary Data Inspection Steps

# %%
# Inspect the shape of your data

# inspect the properties of the data
# check for missing values

# check for mis-labels
# hug your data

# %%
# check shape of dataframe  

dfi.shape
# Out:
# (891, 15)

# %%
# Inspect data properties and missing values

dfi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
891 - 203
# Out:
# 688

# %%
# Missing values 

dfi.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
688/891
# Out:
# 0.7721661054994389

# %%
# Get columns in the data  

dfi.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
cols = dfi.columns.tolist()

# %%
cols
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
# peek at your data 

dfi.head(10)
# Out:
#    survived  pclass      sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3     male  22.0      1      0   7.2500        S   Third
# 1         1       1  female   38.0      1      0  71.2833        C   First
# 2         1       3   female  26.0      0      0   7.9250        S   Third
# 3         1       1   female  35.0      1      0  53.1000        S   First
# 4         0       3     male  35.0      0      0   8.0500        S   Third
# 5         0       3    male    NaN      0      0   8.4583        Q   Third
# 6         0       1     male  54.0      0      0  51.8625        S   First
# 7         0       3     male   2.0      3      1  21.0750        S   Third
# 8         1       3   female  27.0      0      2  11.1333        S   Third
# 9         1       2   female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
dfi.tail()
# Out:
#      survived  pclass      sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2     male  27.0      0      0  13.00        S  Second
# 887         1       1   female  19.0      0      0  30.00        S   First
# 888         0       3  femalER   NaN      1      2  23.45        S   Third
# 889         1       1     male  26.0      0      0  30.00        C   First
# 890         0       3     male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890   man         True  NaN   Queenstown    no   True

# %%
dfi.sample(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 431         1       3  female   NaN      1      0   16.1000        S   Third
# 481         0       2    male   NaN      0      0    0.0000        S  Second
# 819         0       3    male  10.0      3      2   27.9000        S   Third
# 332         0       1    male  38.0      0      1  153.4625        S   First
# 8           1       3  female  27.0      0      2   11.1333        S   Third
# 594         0       2    male  37.0      1      0   26.0000        S  Second
# 483         1       3  female  63.0      0      0    9.5875        S   Third
# 873         0       3    male  47.0      0      0    9.0000        S   Third
# 284         0       1    male   NaN      0      0   26.0000        S   First
# 156         1       3  female  16.0      0      0    7.7333        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 431  woman       False  NaN  Southampton   yes  False
# ...

# %%
dfi['sex'].unique()
# Out:
# array(['male', 'female ', 'female', 'male ', 'Female', 'femalER'],
#       dtype=object)

# %%
dfi.pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
dfi['class'].unique()
# Out:
# array(['Third', 'First', 'Second', 'Second '], dtype=object)

# %%
# Note:

#1. inspect all numeric columns to be sure they are numeric and not reported as type string  
#2. Inspect all categorical features and ensure that the labels are unqiue

#3. Treat all observed errors

# %%
# Cleaning for SEX

# %%
dfi['sex'] =dfi['sex'].replace(['female ', 'male ', 'Female', 'femalER'], ['female', 'male', 'female', 'female'])

# %%
dfi['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
dfi['class'] =dfi['class'].replace('Second ', 'Second' )

# %%
dfi['class'].unique()
# Out:
# array(['Third', 'First', 'Second'], dtype=object)

# %%
# extracting reacords for males  

dfi_males = dfi.loc[dfi['sex']=='male']

# %%
dfi_males
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3  male  22.0      1      0   7.2500        S   Third
# 4           0       3  male  35.0      0      0   8.0500        S   Third
# 5           0       3  male   NaN      0      0   8.4583        Q   Third
# 6           0       1  male  54.0      0      0  51.8625        S   First
# 7           0       3  male   2.0      3      1  21.0750        S   Third
# ..        ...     ...   ...   ...    ...    ...      ...      ...     ...
# 883         0       2  male  28.0      0      0  10.5000        S  Second
# 884         0       3  male  25.0      0      0   7.0500        S   Third
# 886         0       2  male  27.0      0      0  13.0000        S  Second
# 889         1       1  male  26.0      0      0  30.0000        C   First
# 890         0       3  male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
dfi.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
dfi.age.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
dfi.survived.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>
